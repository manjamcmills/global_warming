# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
sea_ice_NH_extent = pd.read_csv("data/sea_ice_NH_extent.csv")
sea_ice_NH_extent.drop(["Unnamed: 13"], axis=1, inplace=True)
sea_ice_NH_extent.rename(columns = {"Unnamed: 0":"year"}, inplace=True)
sea_ice_NH_extent.rename(columns = {"Annual":"Annual Sea Ice NH Extent"}, inplace=True)
sea_ice_NH_extent.set_index('year', inplace=True)
sea_ice_NH_extent.head()
# Out:
#       January  February   March   April     May    June    July  August  \
# year
# 1978      NaN       NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1979   15.414    16.175  16.342  15.447  13.857  12.530  10.311   8.041
# 1980   14.862    15.955  16.041  15.429  13.793  12.205  10.100   7.984
# 1981   14.910    15.604  15.632  15.010  13.802  12.430  10.271   7.844
# 1982   15.177    15.974  16.044  15.466  13.973  12.476  10.367   8.139
#
#       September  October  November  December  Annual Sea Ice NH Extent
# year
# 1978        NaN      NaN    11.645    13.667                    12.673
# 1979      7.051    8.748    10.943    13.336                    12.328
# 1980      7.667    9.183    11.383    13.593                    12.337
# 1981      7.138    8.856    10.929    13.341                    12.127
# 1982      7.302    9.421    11.627    13.642                    12.447

# %%
sea_ice_NH_extent_dict = sea_ice_NH_extent.drop(['Annual Sea Ice NH Extent'], axis=1).T.to_dict()

sea_ice_NH_extent_mo  = []
for x, vals in sea_ice_NH_extent_dict.items():
    for y, z in vals.items():
        sea_ice_NH_extent_mo.append([x,y,z])
        
sea_ice_NH_extent_DF = pd.DataFrame(sea_ice_NH_extent_mo, columns=["Year", "Month", "Sea Ice NH Extent"])
sea_ice_NH_extent_DF
# Out:
#      Year      Month  Sea Ice NH Extent
# 0    1978    January                NaN
# 1    1978   February                NaN
# 2    1978      March                NaN
# 3    1978      April                NaN
# 4    1978        May                NaN
# ..    ...        ...                ...
# 535  2022     August              5.995
# 536  2022  September              4.869
# 537  2022    October                NaN
# 538  2022   November                NaN
# 539  2022   December                NaN
#
# [540 rows x 3 columns]

# %%
sea_ice_NH_extent_annual=pd.DataFrame(sea_ice_NH_extent, columns=['Annual Sea Ice NH Extent'])
sea_ice_NH_extent_annual.rename(columns = {"Annual Sea Ice NH Extent":"Sea Ice NH Extent"}, inplace=True)
sea_ice_NH_extent_annual.head()
# Out:
#       Sea Ice NH Extent
# year
# 1978             12.673
# 1979             12.328
# 1980             12.337
# 1981             12.127
# 1982             12.447

# %%
sea_ice_NH_area = pd.read_csv("data/sea_ice_NH_area.csv")
sea_ice_NH_area.drop(["Unnamed: 13"], axis=1, inplace=True)
sea_ice_NH_area.rename(columns = {"Unnamed: 0":"year"}, inplace=True)
sea_ice_NH_area.rename(columns = {"Annual":"Annual Sea Ice NH Area"}, inplace=True)
sea_ice_NH_area.set_index('year', inplace=True)
sea_ice_NH_area.head()
# Out:
#       January  February   March   April     May   June   July  August  \
# year
# 1978      NaN       NaN     NaN     NaN     NaN    NaN    NaN     NaN
# 1979   12.406    13.181  13.208  12.528  11.109  9.344  6.692   5.056
# 1980   11.938    12.901  12.990  12.522  10.964  9.003  6.535   4.938
# 1981   11.907    12.533  12.714  12.239  10.991  9.029  6.313   4.477
# 1982   12.192    12.868  13.066  12.630  11.169  9.460  6.870   5.003
#
#       September  October  November  December  Annual Sea Ice NH Area
# year
# 1978        NaN      NaN     9.037    10.901                   9.984
# 1979      4.583    6.189     8.367    10.633                   9.418
# 1980      4.871    6.495     8.727    10.781                   9.376
# 1981      4.439    6.265     8.313    10.543                   9.126
# 1982      4.435    6.670     9.059    10.879                   9.504

# %%
sea_ice_NH_area_dict = sea_ice_NH_area.drop(['Annual Sea Ice NH Area'], axis=1).T.to_dict()

sea_ice_NH_area_dict.items()
# Out:
# dict_items([(1978, {'January': nan, 'February': nan, 'March': nan, 'April': nan, 'May': nan, 'June': nan, 'July': nan, 'August': nan, 'September': nan, 'October': nan, 'November': 9.037, 'December': 10.901}), (1979, {'January': 12.406, 'February': 13.181, 'March': 13.208, 'April': 12.528, 'May': 11.109, 'June': 9.344, 'July': 6.692, 'August': 5.056, 'September': 4.583, 'October': 6.189, 'November': 8.367, 'December': 10.633}), (1980, {'January': 11.938, 'February': 12.901, 'March': 12.99, 'April': 12.522, 'May': 10.964, 'June': 9.003, 'July': 6.535, 'August': 4.938, 'September': 4.871, 'October': 6.495, 'November': 8.727, 'December': 10.781}), (1981, {'January': 11.907, 'February': 12.533, 'March': 12.714, 'April': 12.239, 'May': 10.991, 'June': 9.029, 'July': 6.313, 'August': 4.477, 'September': 4.439, 'October': 6.265, 'November': 8.313, 'December': 10.543}), (1982, {'January': 12.192, 'February': 12.868, 'March': 13.066, 'April': 12.63, 'May': 11.169, 'June': 9.46, 'July': 6.87, '
# ...

# %%
sea_ice_NH_area_dict = sea_ice_NH_area.drop(['Annual Sea Ice NH Area'], axis=1).T.to_dict()

sea_ice_NH_area_mo = []
for x,vals in sea_ice_NH_area_dict.items():
    for y, z in vals.items():
        sea_ice_NH_area_mo.append([x,y,z])
        
sea_ice_NH_area_DF = pd.DataFrame(sea_ice_NH_area_mo, columns=["Year", "Month", "Sea Ice NH Area"])
sea_ice_NH_area_DF
# Out:
#      Year      Month  Sea Ice NH Area
# 0    1978    January              NaN
# 1    1978   February              NaN
# 2    1978      March              NaN
# 3    1978      April              NaN
# 4    1978        May              NaN
# ..    ...        ...              ...
# 535  2022     August            4.023
# 536  2022  September            3.435
# 537  2022    October              NaN
# 538  2022   November              NaN
# 539  2022   December              NaN
#
# [540 rows x 3 columns]

# %%
sea_ice_NH_area_annual=pd.DataFrame(sea_ice_NH_area, columns=['Annual Sea Ice NH Area'])
sea_ice_NH_area_annual.rename(columns = {"Annual Sea Ice NH Area":"Sea Ice NH Area"}, inplace=True)
sea_ice_NH_area_annual.head()
# Out:
#       Sea Ice NH Area
# year
# 1978            9.984
# 1979            9.418
# 1980            9.376
# 1981            9.126
# 1982            9.504

# %%
sea_ice_SH_extent = pd.read_csv("data/sea_ice_SH_extent.csv")
sea_ice_SH_extent.drop(["Unnamed: 13"], axis=1, inplace=True)
sea_ice_SH_extent.rename(columns = {"Unnamed: 0":"year"}, inplace=True)
sea_ice_SH_extent.rename(columns = {"Annual":"Annual Sea Ice SH Extent"}, inplace=True)
sea_ice_SH_extent.set_index('year', inplace=True)
sea_ice_SH_extent.head()
# Out:
#       January  February  March  April     May    June    July  August  \
# year
# 1978      NaN       NaN    NaN    NaN     NaN     NaN     NaN     NaN
# 1979    5.402     3.141  3.999  7.486  10.827  14.187  16.517  17.698
# 1980    4.562     2.818  3.295  5.405   8.857  12.490  15.564  17.805
# 1981    4.412     2.873  3.392  5.838   9.355  13.109  16.039  17.737
# 1982    5.260     3.129  4.288  7.723  10.758  13.417  15.872  17.789
#
#       September  October  November  December  Annual Sea Ice SH Extent
# year
# 1978        NaN      NaN    15.896    10.395                    13.101
# 1979     18.196   17.820    15.337     9.236                    11.700
# 1980     18.817   18.568    16.133    10.156                    11.230
# 1981     18.597   18.294    16.111    10.895                    11.435
# 1982     18.353   17.789    15.537     9.216                    11.640

# %%
sea_ice_SH_extent_dict = sea_ice_SH_extent.drop(['Annual Sea Ice SH Extent'], axis=1).T.to_dict()

sea_ice_SH_extent_mo  = []
for x, vals in sea_ice_SH_extent_dict.items():
    for y, z in vals.items():
        sea_ice_SH_extent_mo.append([x,y,z])
        
sea_ice_SH_extent_DF = pd.DataFrame(sea_ice_SH_extent_mo, columns=["Year", "Month", "Sea Ice SH Extent"])
sea_ice_SH_extent_DF
# Out:
#      Year      Month  Sea Ice SH Extent
# 0    1978    January                NaN
# 1    1978   February                NaN
# 2    1978      March                NaN
# 3    1978      April                NaN
# 4    1978        May                NaN
# ..    ...        ...                ...
# 535  2022     August             16.974
# 536  2022  September             18.007
# 537  2022    October                NaN
# 538  2022   November                NaN
# 539  2022   December                NaN
#
# [540 rows x 3 columns]

# %%
sea_ice_SH_extent_annual=pd.DataFrame(sea_ice_SH_extent, columns=['Annual Sea Ice SH Extent'])
sea_ice_SH_extent_annual.rename(columns = {"Annual Sea Ice SH Extent":"Sea Ice SH Extent"}, inplace=True)
sea_ice_SH_extent_annual.head()
# Out:
#       Sea Ice SH Extent
# year
# 1978             13.101
# 1979             11.700
# 1980             11.230
# 1981             11.435
# 1982             11.640

# %%
sea_ice_SH_area = pd.read_csv("data/sea_ice_SH_area.csv")
sea_ice_SH_area.drop(["Unnamed: 13"], axis=1, inplace=True)
sea_ice_SH_area.rename(columns = {"Unnamed: 0":"year"}, inplace=True)
sea_ice_SH_area.rename(columns = {"Annual":"Annual Sea Ice SH Area"}, inplace=True)
sea_ice_SH_area.set_index('year', inplace=True)
sea_ice_SH_area.head()
# Out:
#       January  February  March  April    May    June    July  August  \
# year
# 1978      NaN       NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 1979    3.474     2.107  2.663  5.452  8.299  11.224  13.257  13.785
# 1980    3.082     1.847  2.110  3.678  6.437   9.581  12.180  13.956
# 1981    2.841     1.737  2.155  4.073  7.077  10.163  12.777  14.156
# 1982    3.251     1.860  2.841  5.792  8.273  10.498  12.473  14.284
#
#       September  October  November  December  Annual Sea Ice SH Area
# year
# 1978        NaN      NaN    11.686     6.969                   9.289
# 1979     14.287   13.722    11.322     6.236                   8.855
# 1980     14.866   14.568    11.841     6.559                   8.410
# 1981     14.781   14.433    12.073     7.015                   8.645
# 1982     14.529   13.745    11.269     6.314                   8.798

# %%
sea_ice_SH_area_dict = sea_ice_SH_area.drop(['Annual Sea Ice SH Area'], axis=1).T.to_dict()

sea_ice_SH_area_mo = []
for x,vals in sea_ice_SH_area_dict.items():
    for y, z in vals.items():
        sea_ice_SH_area_mo.append([x,y,z])
        
sea_ice_SH_area_DF = pd.DataFrame(sea_ice_SH_area_mo, columns=["Year", "Month", "Sea Ice SH Area"])
sea_ice_SH_area_DF
# Out:
#      Year      Month  Sea Ice SH Area
# 0    1978    January              NaN
# 1    1978   February              NaN
# 2    1978      March              NaN
# 3    1978      April              NaN
# 4    1978        May              NaN
# ..    ...        ...              ...
# 535  2022     August           13.664
# 536  2022  September           14.046
# 537  2022    October              NaN
# 538  2022   November              NaN
# 539  2022   December              NaN
#
# [540 rows x 3 columns]

# %%
sea_ice_SH_area_annual=pd.DataFrame(sea_ice_SH_area, columns=['Annual Sea Ice SH Area'])
sea_ice_SH_area_annual.rename(columns = {"Annual Sea Ice SH Area":"Sea Ice SH Area"}, inplace=True)
sea_ice_SH_area_annual.head()
# Out:
#       Sea Ice SH Area
# year
# 1978            9.289
# 1979            8.855
# 1980            8.410
# 1981            8.645
# 1982            8.798

# %%
sea_ice_annual_list = [sea_ice_NH_extent_annual,sea_ice_NH_area_annual,sea_ice_SH_extent_annual,sea_ice_SH_area_annual]

# %%
sea_ice_annual_merged = sea_ice_NH_extent_annual.merge(sea_ice_NH_area_annual, on ='year').merge(sea_ice_SH_extent_annual, on='year').merge(sea_ice_SH_area_annual, on='year')

# %%
sea_ice_annual_merged = sea_ice_annual_merged.rename(columns={'Sea Ice NH Extent':'NH Extent', 'Sea Ice NH Area':'NH Area','Sea Ice SH Extent':'SH Extent', 'Sea Ice SH Area':'SH Area' })
sea_ice_annual_merged.head()
# Out:
#       NH Extent  NH Area  SH Extent  SH Area
# year
# 1978     12.673    9.984     13.101    9.289
# 1979     12.328    9.418     11.700    8.855
# 1980     12.337    9.376     11.230    8.410
# 1981     12.127    9.126     11.435    8.645
# 1982     12.447    9.504     11.640    8.798

# %%
sea_ice_annual_merged.columns
# Out:
# Index(['NH Extent', 'NH Area', 'SH Extent', 'SH Area'], dtype='object')

# %%
sea_ice = sea_ice_annual_merged
sea_ice
# Out:
#       NH Extent  NH Area  SH Extent  SH Area
# year
# 1978     12.673    9.984     13.101    9.289
# 1979     12.328    9.418     11.700    8.855
# 1980     12.337    9.376     11.230    8.410
# 1981     12.127    9.126     11.435    8.645
# 1982     12.447    9.504     11.640    8.798
# 1983     12.332    9.408     11.389    8.572
# 1984     11.910    9.001     11.454    8.707
# 1985     11.995    9.085     11.618    8.867
# 1986     12.203    9.275     11.088    8.304
# 1987     12.135    9.967     11.554    8.796
# 1988     11.923    9.889     12.131    9.243
# 1989     11.967    9.913     11.426    8.716
# 1990     11.694    9.645     11.410    8.697
# 1991     11.749    9.722     11.545    8.710
# 1992     12.110   10.086     11.399    8.544
# 1993     11.923    9.786     11.420    8.652
# 1994     12.011    9.968     11.774    9.069
# 1995     11.415    9.403     11.795    8.906
# 1996     11.841    9.791     11.769    8.838
# 1997     11.668    9.593     11.390    8.695
# ...

# %%
sea_ice = sea_ice.rename(columns = {'NH Extent':'NH_Extent', 'NH Area':'NH_Area', 'SH Extent':'SH_Extent', 'SH Area':'SH_Area'})
sea_ice
# Out:
#       NH_Extent  NH_Area  SH_Extent  SH_Area
# year
# 1978     12.673    9.984     13.101    9.289
# 1979     12.328    9.418     11.700    8.855
# 1980     12.337    9.376     11.230    8.410
# 1981     12.127    9.126     11.435    8.645
# 1982     12.447    9.504     11.640    8.798
# 1983     12.332    9.408     11.389    8.572
# 1984     11.910    9.001     11.454    8.707
# 1985     11.995    9.085     11.618    8.867
# 1986     12.203    9.275     11.088    8.304
# 1987     12.135    9.967     11.554    8.796
# 1988     11.923    9.889     12.131    9.243
# 1989     11.967    9.913     11.426    8.716
# 1990     11.694    9.645     11.410    8.697
# 1991     11.749    9.722     11.545    8.710
# 1992     12.110   10.086     11.399    8.544
# 1993     11.923    9.786     11.420    8.652
# 1994     12.011    9.968     11.774    9.069
# 1995     11.415    9.403     11.795    8.906
# 1996     11.841    9.791     11.769    8.838
# 1997     11.668    9.593     11.390    8.695
# ...

# %%
sea_ice.columns
# Out:
# Index(['NH_Extent', 'NH_Area', 'SH_Extent', 'SH_Area'], dtype='object')

# %%
sea_ice_global = sea_ice.copy()
sea_ice_global['Global Sea Ice Area'] = sea_ice_global.loc['1978':'2022', ['NH_Area',  'SH_Area']].sum(axis=1)
sea_ice_global['Global Sea Ice Extent'] = sea_ice_global.loc['1978':'2022', ['NH_Extent',  'SH_Extent']].sum(axis=1)
sea_ice_global.head()
# Out:
#       NH_Extent  NH_Area  SH_Extent  SH_Area  Global Sea Ice Area  \
# year
# 1978     12.673    9.984     13.101    9.289               19.273
# 1979     12.328    9.418     11.700    8.855               18.273
# 1980     12.337    9.376     11.230    8.410               17.786
# 1981     12.127    9.126     11.435    8.645               17.771
# 1982     12.447    9.504     11.640    8.798               18.302
#
#       Global Sea Ice Extent
# year
# 1978                 25.774
# 1979                 24.028
# 1980                 23.567
# 1981                 23.562
# 1982                 24.087

# %%
sea_ice_global=sea_ice_global['Global Sea Ice'] 
sea_ice_global
# Out:
# year
# 1978    19.273
# 1979    18.273
# 1980    17.786
# 1981    17.771
# 1982    18.302
# 1983    17.980
# 1984    17.708
# 1985    17.952
# 1986    17.579
# 1987    18.763
# 1988    19.132
# 1989    18.629
# 1990    18.342
# 1991    18.432
# 1992    18.630
# 1993    18.438
# 1994    19.037
# 1995    18.309
# 1996    18.629
# 1997    18.288
# 1998    18.453
# 1999    18.541
# 2000    18.459
# 2001    18.302
# 2002    17.874
# 2003    18.368
# 2004    18.423
# 2005    17.787
# 2006    17.484
# 2007    17.420
# 2008    18.520
# 2009    18.405
# 2010    18.119
# 2011    17.478
# 2012    17.875
# 2013    18.914
# 2014    18.953
# 2015    18.321
# 2016    16.681
# 2017    16.804
# 2018    17.035
# 2019    16.928
# 2020    17.303
# 2021    17.529
# 2022    16.608
# Name: Global Sea Ice, dtype: float64

# %%
sea_ice_global.to_json("global_sea_ice.json")

# %%
sea_ice.to_json("sea_ice.json")

# %%
sea_ice_annual_merged.index
# Out:
# Int64Index([1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988,
#             1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999,
#             2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#             2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021,
#             2022],
#            dtype='int64', name='year')

# %%
year = sea_ice_annual_merged.index
NH_Extent = sea_ice_annual_merged['NH Extent']
NH_Area = sea_ice_annual_merged['NH Area']
SH_Extent = sea_ice_annual_merged['SH Extent']
SH_Area = sea_ice_annual_merged['SH Area']

# %%
from matplotlib.pyplot import figure
plt.figure(figsize = (20,5))
#plt.plot(year,NH_Extent, la1el="NH_Extent" )
plt.plot(year,NH_Area, label="NH_Area" )
#plt.plot(year,SH_Extent, label="SH_Extent" )
plt.plot(year,SH_Area, label="SH_Area" )

plt.title("Northern and Southern Hemisphere Area")
plt.xlabel("year")
plt.legend()
plt.show()

# %%
from matplotlib.pyplot import figure
plt.figure(figsize = (20,5))
plt.plot(year,NH_Extent, label="NH_Extent" )
#plt.plot(year,NH_Area, label="NH_Area" )
plt.plot(year,SH_Extent, label="SH_Extent" )
#plt.plot(year,SH_Area, label="SH_Area" )

plt.title("Northern and Southern Hemisphere Extent")
plt.xlabel("year")
plt.legend()
plt.show()

# %%
from matplotlib.pyplot import figure
plt.figure(figsize = (20,5))
plt.plot(year,NH_Extent, label="NH_Extent" )
plt.plot(year,NH_Area, label="NH_Area" )
#plt.plot(year,SH_Extent, label="SH_Extent" )
#plt.plot(year,SH_Area, label="SH_Area" )

plt.title("Northern Hemisphere Aread and Extent")
plt.xlabel("year")
plt.legend()
plt.show()

# %%
from matplotlib.pyplot import figure
plt.figure(figsize = (20,5))
#plt.plot(year,NH_Extent, label="NH_Extent" )
#plt.plot(year,NH_Area, label="NH_Area" )
plt.plot(year,SH_Extent, label="SH_Extent" )
plt.plot(year,SH_Area, label="SH_Area" )

plt.title("Southern Hemisphere Aread and Extent")
plt.xlabel("year")
plt.legend()
plt.show()

# %%
from sklearn.linear_model import LinearRegression
sea_ice_SH_area_annual =sea_ice_SH_area_annual.reset_index()
X = sea_ice_SH_area_annual.year.values.reshape(-1, 1)
y = sea_ice_SH_area_annual['Sea Ice SH Area']
model_SH_area = LinearRegression()
model_SH_area.fit(X, y)
y_pred_SH_area  = model_SH_area.predict(X)
plt.scatter(X, y)
plt.plot(X, y_pred_SH_area , color='red')
plt.show()

# %%
print(model_SH_area.coef_)
print(model_SH_area.intercept_)
# Out:
# [-0.00084651]
# 10.507617127799747

# %%
from sklearn.linear_model import LinearRegression
sea_ice_NH_area_annual =sea_ice_NH_area_annual.reset_index()
X = sea_ice_NH_area_annual.year.values.reshape(-1, 1)
y = sea_ice_NH_area_annual['Sea Ice NH Area']
model_NH_area = LinearRegression()
model_NH_area.fit(X, y)
y_pred_NH_area  = model_NH_area.predict(X)
plt.scatter(X, y)
plt.plot(X, y_pred_NH_area , color='red')
plt.show()

# %%
print(model_NH_area.coef_)
print(model_NH_area.intercept_)
# Out:
# [-0.0234697]
# 56.210060606060615

# %%
sea_ice_NH_area_DF
# Out:
#      Year      Month  Sea Ice NH Area
# 0    1978    January              NaN
# 1    1978   February              NaN
# 2    1978      March              NaN
# 3    1978      April              NaN
# 4    1978        May              NaN
# ..    ...        ...              ...
# 535  2022     August            4.023
# 536  2022  September            3.435
# 537  2022    October              NaN
# 538  2022   November              NaN
# 539  2022   December              NaN
#
# [540 rows x 3 columns]

# %%
sea_ice_area_merged_month = pd.concat([sea_ice_NH_area_DF, sea_ice_SH_area_DF], axis=0)
sea_ice_area_merged_month
# Out:
#      Year      Month  Sea Ice NH Area  Sea Ice SH Area
# 0    1978    January              NaN              NaN
# 1    1978   February              NaN              NaN
# 2    1978      March              NaN              NaN
# 3    1978      April              NaN              NaN
# 4    1978        May              NaN              NaN
# ..    ...        ...              ...              ...
# 535  2022     August              NaN           13.664
# 536  2022  September              NaN           14.046
# 537  2022    October              NaN              NaN
# 538  2022   November              NaN              NaN
# 539  2022   December              NaN              NaN
#
# [1080 rows x 4 columns]
