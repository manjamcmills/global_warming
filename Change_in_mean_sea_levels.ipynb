# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
sealevels_mean = pd.read_csv('Change_in_Mean_Sea_Levels.csv')

# %%
sealevels_mean
# Out:
#        ObjectId Country  ISO2 ISO3  \
# 0             1   World   NaN  WLD
# 1             2   World   NaN  WLD
# 2             3   World   NaN  WLD
# 3             4   World   NaN  WLD
# 4             5   World   NaN  WLD
# ...         ...     ...   ...  ...
# 35374     35375   World   NaN  WLD
# 35375     35376   World   NaN  WLD
# 35376     35377   World   NaN  WLD
# 35377     35378   World   NaN  WLD
# 35378     35379   World   NaN  WLD
#
#                                                Indicator         Unit  \
# 0      Change in mean sea level: Sea level: TOPEX.Pos...  Millimeters
# 1      Change in mean sea level: Sea level: TOPEX.Pos...  Millimeters
# 2      Change in mean sea level: Sea level: TOPEX.Pos...  Millimeters
# 3      Change in mean sea level: Sea level: TOPEX.Pos...  Millimeters
# 4      Change in mean sea level: Sea level: TOPEX.Pos...  Millimeters
# ...                                                  ...          ...
# ...
